# %% [markdown]
# <a href="https://colab.research.google.com/github/baochuong/Articial-Intelligence-AI-/blob/main/Machine_learning(socialNetworkAds).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sas
from sklearn.preprocessing import  StandardScaler as S_scaler

# %%
data = pd.read_csv('Social_Network_Ads.csv')
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
sas.pairplot(data)

# %%
corr = data.corr()
sas.heatmap(corr, annot= True)
# Out:
# <Axes: >

# %%
y = data['Age']
data = data.drop(data.columns[[0]], axis = 1)
data = data.replace("Male",1)
data = data.replace("Female",0)
data.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0       1   19            19000          0
# 1       1   35            20000          0
# 2       0   26            43000          0
# 3       0   27            57000          0
# 4       1   19            76000          0

# %%
sas.pairplot(data)

# %%
corr = data.corr()
sas.heatmap(corr,annot = True)
# Out:
# <Axes: >

# %%
X = data.drop(data.columns[[2]], axis = True)
sc = S_scaler()
X = sc.fit_transform(x)

# %%
from sklearn.preprocessing import StandardScaler
SC = StandardScaler()
X = SC.fit_transform(X)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (80,)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test).round(1)
colculatinon = pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profit','Predictor Profit'])
print("Do chinh xac train:",regressor.score(X_train,y_train))
print("Do chinh xac test:",regressor.score(X_test,y_test))
# Out:
# Do chinh xac train: 1.0
# Do chinh xac test: 1.0

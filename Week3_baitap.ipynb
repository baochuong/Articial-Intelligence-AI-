# %% [markdown]
# <a href="https://colab.research.google.com/github/baochuong/Articial-Intelligence-AI-/blob/main/Week3_baitap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
data[(data['NOC']=='USA') & (data['Medal']=='Gold') & (data['Event']=='individual')]
# Out:
#       Year               City      Sport      Discipline  NOC       Event  \
# 86    1928         St. Moritz  Bobsleigh        Skeleton  USA  individual
# 246   1948         St. Moritz    Skating  Figure skating  USA  individual
# 311   1952               Oslo    Skating  Figure skating  USA  individual
# 386   1956  Cortina d'Ampezzo    Skating  Figure skating  USA  individual
# 388   1956  Cortina d'Ampezzo    Skating  Figure skating  USA  individual
# 462   1960       Squaw Valley    Skating  Figure skating  USA  individual
# 464   1960       Squaw Valley    Skating  Figure skating  USA  individual
# 674   1968           Grenoble    Skating  Figure skating  USA  individual
# 887   1976          Innsbruck    Skating  Figure skating  USA  individual
# 1119  1984           Sarajevo    Skating  Figure skating  USA  individual
# 1257  1988            Calgary    Skating  Figure skating  USA  individual
# 1428  1992        Albertville    Skating  Figure skating  USA  individual
# ...

# %%
datas=data[(data['NOC'] =='CAN')]
print("Số huy chương của CAN:",datas['Medal'].count())
data1=data[(data['Event'] =='individual') & (data['Medal']=='Gold')] 
print("Số huy chương chương vàng theo môn cá nhân:",data1['Event'].count())
# Out:
# Số huy chương của CAN: 119
# Số huy chương chương vàng theo môn cá nhân: 65

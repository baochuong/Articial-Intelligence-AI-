# %% [markdown]
# <a href="https://colab.research.google.com/github/baochuong/Articial-Intelligence-AI-/blob/main/Machine_learning(USAHousing).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sas
from sklearn.preprocessing import  StandardScaler as S_scaler

# %%
data = pd.read_csv('USA_Housing.csv')
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
sas.pairplot(data)

# %%
corr = data.corr()
sas.heatmap(corr, annot= True)
# Out:
# <Axes: >

# %%
data = data.drop(data.columns[[0,6]], axis = 1)
y = data['Price']
data.head()
# Out:
#    Avg. Area House Age  Avg. Area Number of Rooms  \
# 0             5.682861                   7.009188
# 1             6.002900                   6.730821
# 2             5.865890                   8.512727
# 3             7.188236                   5.586729
# 4             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %%
sas.pairplot(data)

# %%
corr = data.corr()
sas.heatmap(corr, annot= True)
# Out:
# <Axes: >

# %%
X = data.drop(data.columns[[4]], axis = 1)
sc = S_scaler()
X = sc.fit_transform(x)

# %%
from sklearn.preprocessing import StandardScaler
SC = StandardScaler()
X = SC.fit_transform(X)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)
X_train.shape
X_test.shape
y_train.shape
y_test.shape
# Out:
# (1000,)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test).round(1)
colculatinon = pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profit','Predictor Profit'])
print("Do chinh xac train:",regressor.score(X_train,y_train))
print("Do chinh xac test:",regressor.score(X_test,y_test))
# Out:
# Do chinh xac train: 0.4919209985053704
# Do chinh xac test: 0.503743625896899
